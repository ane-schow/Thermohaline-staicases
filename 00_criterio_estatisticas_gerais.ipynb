# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import Normalize
import glob
import os

# %%
nc_files = sorted( glob.glob( r"C:\Users\locfa_v05v5qi\Documents\escadas_termohalinas\raw\Dataset\**\*.nc", recursive=True ) )

# %%
def subset_region(ds):
    # Ajustar longitudes se estiverem em 0–360
    if ds.lon.max() > 180:
        ds = ds.assign_coords(
            lon=((ds.lon + 180) % 360) - 180
        )

    # Criar máscara apenas para a dimensão n (perfis)
    mask = (
        (ds.lat <= 10) & (ds.lat >= -60) &
        (ds.lon >= -50) & (ds.lon <= -10)
    )

    if "Nobs" in ds.dims:
        ds = ds.isel(Nobs=mask)

    return ds
    
def check_staircase_exists(ml_h, gl_h): #verifica se os valores são fisicamente válidos (n só se existem)

    valid_ml = np.sum(~np.isnan(ml_h) & (ml_h > 0))
    valid_gl = np.sum(~np.isnan(gl_h) & (gl_h > 0))

    return (valid_ml >= 1) and (valid_gl >= 1)
    
def detect_staircases(ds):

    profile_dim = ds.lat.dims[0]
    n_profiles = ds.sizes[profile_dim] #p n ter problema d confundir "n" e "Nobs"

    staircase_sf = np.zeros(n_profiles, dtype=bool)
    staircase_dc = np.zeros(n_profiles, dtype=bool)

    for i in range(n_profiles):

        # =========================
        # SALT FINGER
        # =========================
        ml_mask_sf = ds.mask_ml_sf_layer.isel({profile_dim: i}) > 0
        gl_mask_sf = ds.mask_gl_sf_layer.isel({profile_dim: i}) > 0

        ml_h_sf = ds.ml_h.isel({profile_dim: i}).values[ml_mask_sf.values] #pega os valores onde ml_mask_sf é True 
        gl_h_sf = ds.gl_h.isel({profile_dim: i}).values[gl_mask_sf.values]

        if len(ml_h_sf) > 0 and len(gl_h_sf) > 0:
            staircase_sf[i] = check_staircase_exists(
                ml_h_sf, gl_h_sf
            )

        # =========================
        # DIFFUSIVE CONVECTION
        # =========================
        ml_mask_dc = ds.mask_ml_dc_layer.isel({profile_dim: i}) > 0
        gl_mask_dc = ds.mask_gl_dc_layer.isel({profile_dim: i}) > 0

        ml_h_dc = ds.ml_h.isel({profile_dim: i}).values[ml_mask_dc.values]
        gl_h_dc = ds.gl_h.isel({profile_dim: i}).values[gl_mask_dc.values]

        if len(ml_h_dc) > 0 and len(gl_h_dc) > 0:
            staircase_dc[i] = check_staircase_exists(
                ml_h_dc, gl_h_dc
            )

    ds["staircase_sf"] = (profile_dim, staircase_sf)
    ds["staircase_dc"] = (profile_dim, staircase_dc)

    return ds

# %%
import numpy as np

def diagnose_coordinates(ds, profile_dim="Nobs"):

    print("\n================ DIAGNÓSTICO ESPACIAL ================")

    lat = ds.lat.values
    lon = ds.lon.values
    n = len(lat)

    print("Total de perfis analisados:", n)

    # ----------------------------------------------------
    # 1️⃣ Verificar NaN / Inf
    # ----------------------------------------------------
    nan_lat = np.isnan(lat)
    nan_lon = np.isnan(lon)
    inf_lat = np.isinf(lat)
    inf_lon = np.isinf(lon)

    print("\n--- Valores inválidos ---")
    print("Lat NaN:", np.sum(nan_lat))
    print("Lon NaN:", np.sum(nan_lon))
    print("Lat Inf:", np.sum(inf_lat))
    print("Lon Inf:", np.sum(inf_lon))

    invalid_idx = np.where(nan_lat | nan_lon | inf_lat | inf_lon)[0]
    if len(invalid_idx) > 0:
        print("Perfis com coordenadas inválidas (primeiros 10):", invalid_idx[:10])

    # ----------------------------------------------------
    # 2️⃣ Range esperado
    # ----------------------------------------------------
    print("\n--- Faixa de valores ---")
    print("Lat min/max:", np.nanmin(lat), "/", np.nanmax(lat))
    print("Lon min/max:", np.nanmin(lon), "/", np.nanmax(lon))

    if np.nanmax(lat) > 90 or np.nanmin(lat) < -90:
        print("⚠️ Latitude fora do intervalo físico (-90, 90)")

    if np.nanmax(lon) > 360 or np.nanmin(lon) < -180:
        print("⚠️ Longitude fora do intervalo esperado")

    # ----------------------------------------------------
    # 3️⃣ Sistema de longitude
    # ----------------------------------------------------
    if np.nanmax(lon) > 180:
        print("🌍 Longitude parece estar em 0–360")
    else:
        print("🌍 Longitude parece estar em -180–180")

    # ----------------------------------------------------
    # 4️⃣ Coordenadas duplicadas exatas
    # ----------------------------------------------------
    coords = list(zip(lat, lon))
    unique_coords = set(coords)

    print("\n--- Repetição exata ---")
    print("Total pontos:", len(coords))
    print("Pontos únicos:", len(unique_coords))
    print("Repetidos exatos:", len(coords) - len(unique_coords))

    # ----------------------------------------------------
    # 5️⃣ Resolução real das coordenadas
    # ----------------------------------------------------
    lat_sorted = np.sort(np.unique(lat[~np.isnan(lat)]))
    lon_sorted = np.sort(np.unique(lon[~np.isnan(lon)]))

    lat_diff = np.diff(lat_sorted)
    lon_diff = np.diff(lon_sorted)

    print("\n--- Resolução espacial ---")

    if len(lat_diff) > 0:
        print("Menor Δlat:", np.min(lat_diff))
        print("Mediana Δlat:", np.median(lat_diff))

    if len(lon_diff) > 0:
        print("Menor Δlon:", np.min(lon_diff))
        print("Mediana Δlon:", np.median(lon_diff))

    # ----------------------------------------------------
    # 6️⃣ Saltos anômalos
    # ----------------------------------------------------
    print("\n--- Saltos espaciais entre perfis consecutivos ---")

    dlat = np.abs(np.diff(lat))
    dlon = np.abs(np.diff(lon))

    big_jump = np.where((dlat > 10) | (dlon > 10))[0]

    print("Saltos >10° encontrados:", len(big_jump))

    if len(big_jump) > 0:
        print("Perfis com salto grande (primeiros 10):", big_jump[:10])

    # ----------------------------------------------------
    # 7️⃣ Sensibilidade ao arredondamento
    # ----------------------------------------------------
    print("\n--- Sensibilidade ao arredondamento ---")

    for decimals in [4, 3, 2, 1]:
        lat_r = np.round(lat, decimals)
        lon_r = np.round(lon, decimals)
        n_unique = len(set(zip(lat_r, lon_r)))
        print(f"{decimals} casas decimais → {n_unique} pontos únicos")

    print("\n================ FIM DO DIAGNÓSTICO ==================\n")

# %%
# =========================================================
# CONTADORES GERAIS
# =========================================================

total_profiles = 0
total_profiles_region = 0
total_profiles_stair = 0

total_profiles_sf = 0
total_profiles_dc = 0
total_profiles_mixed = 0

# Estatísticas verticais
all_ml_depth_sf = []
all_ml_depth_dc = []

all_ml_thickness_sf = []
all_ml_thickness_dc = []

n_layers_sf = []
n_layers_dc = []

# Pontos espaciais
all_points = []
all_points_stair = []
all_points_sf = []
all_points_dc = []
all_points_mixed = []

results = []

# =========================================================
# LOOP PRINCIPAL
# =========================================================

for file in nc_files:

    print(f"\nProcessando: {os.path.basename(file)}")

    ds = xr.open_dataset(file)

    # ---------------- PERFIS GLOBAIS ----------------
    n_global = ds.sizes.get("Nobs", 0)
    total_profiles += n_global
    print("Perfis globais:", n_global)

    # ---------------- RECORTE ----------------
    ds = subset_region(ds)
    
    n_region = ds.sizes.get("Nobs", 0)
    total_profiles_region += n_region
    print("Perfis na região:", n_region)
    
    if ds.sizes.get("Nobs", 0) > 0:
        diagnose_coordinates(ds)
    
    if n_region == 0:
        continue

    # ---------------- DETECÇÃO ----------------
    ds = detect_staircases(ds)

    sf_mask = ds.staircase_sf #array booleano por perfil
    dc_mask = ds.staircase_dc
    stair_mask = (sf_mask | dc_mask) #total de perfis
    mixed_mask = (sf_mask & dc_mask)

    n_sf = int(sf_mask.sum())
    n_dc = int(dc_mask.sum())
    n_mixed = int(mixed_mask.sum())
    n_stair = int(stair_mask.sum())

    total_profiles_sf += n_sf
    total_profiles_dc += n_dc
    total_profiles_mixed += n_mixed
    total_profiles_stair += n_stair

    # ---------------- ESTATÍSTICAS VERTICAIS ----------------

    for i in range(n_region):

        if sf_mask.values[i]:

            ml_p = ds.ml_p.isel(Nobs=i).values
            ml_h = ds.ml_h.isel(Nobs=i).values

            valid = (
                ~np.isnan(ml_h) &
                ~np.isnan(ml_p) &
                (ml_h > 0)
            )

            all_ml_depth_sf.extend(ml_p[valid]) #adiciona elemento por elemento a lista
            all_ml_thickness_sf.extend(ml_h[valid])
            n_layers_sf.append(np.sum(valid)) #dá p fazer número médio de camadas por perfil SF

        if dc_mask.values[i]:

            ml_p = ds.ml_p.isel(Nobs=i).values
            ml_h = ds.ml_h.isel(Nobs=i).values

            valid = (
                ~np.isnan(ml_h) &
                ~np.isnan(ml_p) &
                (ml_h > 0)
            )

            all_ml_depth_dc.extend(ml_p[valid])
            all_ml_thickness_dc.extend(ml_h[valid])
            n_layers_dc.append(np.sum(valid))

    # ---------------- PONTOS ESPACIAIS ----------------

    lat = ds.lat.values
    lon = ds.lon.values

    lat_round = np.round(lat, 2)
    lon_round = np.round(lon, 2)

    for la, lo in zip(lat_round, lon_round):
        all_points.append((la, lo))

    for la, lo in zip(lat_round[stair_mask.values],
                      lon_round[stair_mask.values]):
        all_points_stair.append((la, lo))

    for la, lo in zip(lat_round[sf_mask.values],
                      lon_round[sf_mask.values]):
        all_points_sf.append((la, lo))

    for la, lo in zip(lat_round[dc_mask.values],
                      lon_round[dc_mask.values]):
        all_points_dc.append((la, lo))

    for la, lo in zip(lat_round[mixed_mask.values],
                      lon_round[mixed_mask.values]):
        all_points_mixed.append((la, lo))

    subset = ds[[
        "lat",
        "lon",
        "juld",
        "staircase_sf",
        "staircase_dc"
    ]]

    results.append(subset)


# =========================================================
# RESULTADOS FINAIS
# =========================================================

unique_points = set(all_points)
unique_points_stair = set(all_points_stair)
unique_points_sf = set(all_points_sf)
unique_points_dc = set(all_points_dc)
unique_points_mixed = set(all_points_mixed)

print("\n================ RESULTADOS ==================")

print("\n----- PERFIS -----")
print("Perfis globais:", total_profiles)
print("Perfis na região:", total_profiles_region)
print("Perfis com escada:", total_profiles_stair)
print("Perfis SF:", total_profiles_sf)
print("Perfis DC:", total_profiles_dc)
print("Perfis mistos:", total_profiles_mixed)

if total_profiles_region > 0:
    print("\nFrequência total de escadas:",
          round(100 * total_profiles_stair / total_profiles_region, 2), "%")

print("\n----- PONTOS ÚNICOS -----")
print("Pontos únicos na região:", len(unique_points))
print("Pontos únicos com escada:", len(unique_points_stair))
print("Pontos únicos SF:", len(unique_points_sf))
print("Pontos únicos DC:", len(unique_points_dc))
print("Pontos únicos mistos:", len(unique_points_mixed))

if len(unique_points) > 0:
    freq_spatial = len(unique_points_stair) / len(unique_points)
    print("Frequência espacial total:",
          round(freq_spatial * 100, 2), "%")

# =========================================================
# ESTATÍSTICAS VERTICAIS
# =========================================================

print("\n----- ESTATÍSTICAS VERTICAIS -----")

if len(all_ml_depth_sf) > 0:
    print("Profundidade média ML SF:",
          round(np.nanmean(all_ml_depth_sf), 1), "dbar")

if len(all_ml_depth_dc) > 0:
    print("Profundidade média ML DC:",
          round(np.nanmean(all_ml_depth_dc), 1), "dbar")

if len(all_ml_thickness_sf) > 0:
    print("Espessura média ML SF:",
          round(np.mean(all_ml_thickness_sf), 2), "dbar")

if len(all_ml_thickness_dc) > 0:
    print("Espessura média ML DC:",
          round(np.mean(all_ml_thickness_dc), 2), "dbar")

if len(n_layers_sf) > 0:
    print("Número médio de camadas SF:",
          round(np.mean(n_layers_sf), 2))

if len(n_layers_dc) > 0:
    print("Número médio de camadas DC:",
          round(np.mean(n_layers_dc), 2))


# =========================================================
# SALVAR DATASET FINAL
# =========================================================

if results:
    final_ds = xr.concat(results, dim="Nobs")
    final_ds.to_netcdf("staircases_subset_region.nc")
# Out:
# Processando: argo_00000000_00000249.nc
# Perfis globais: 4
# Perfis na região: 0
#
# Processando: argo_00000250_00000499.nc
# Perfis globais: 40
# Perfis na região: 0
#
# Processando: argo_00000500_00000749.nc
# Perfis globais: 827
# Perfis na região: 0
#
# Processando: argo_00000750_00000999.nc
# Perfis globais: 367
# Perfis na região: 22
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 22
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: 7.151 / 8.412
# Lon min/max: -28.666 / -26.583
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 22
# Pontos únicos: 22
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.00399971
# Mediana Δlat: 0.032000065
# Menor Δlon: 0.00399971
# Mediana Δlon: 0.070999146
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 22 pontos únicos
# 3 casas decimais → 22 pontos únicos
# 2 casas decimais → 22 pontos únicos
# 1 casas decimais → 20 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00001000_00001249.nc
# Perfis globais: 3017
# Perfis na região: 198
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 198
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -49.928 / -17.22
# Lon min/max: -45.67121 / -10.005
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 198
# Pontos únicos: 198
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.034999847
# Menor Δlon: 0.0009994507
# Mediana Δlon: 0.048999786
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 2
# Perfis com salto grande (primeiros 10): [116 179]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 198 pontos únicos
# 3 casas decimais → 198 pontos únicos
# 2 casas decimais → 198 pontos únicos
# 1 casas decimais → 189 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00001250_00001499.nc
# Perfis globais: 3591
# Perfis na região: 524
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 524
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -47.913 / 9.99
# Lon min/max: -49.708 / -10.008
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 524
# Pontos únicos: 524
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.021000057
# Menor Δlon: 0.0007133484
# Mediana Δlon: 0.04500103
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 9
# Perfis com salto grande (primeiros 10): [ 19 150 180 181 186 326 413 483 518]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 524 pontos únicos
# 3 casas decimais → 524 pontos únicos
# 2 casas decimais → 524 pontos únicos
# 1 casas decimais → 507 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00001500_00001749.nc
# Perfis globais: 25540
# Perfis na região: 6356
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 6356
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -52.8406 / 9.99814
# Lon min/max: -49.93525 / -10.00942
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 6356
# Pontos únicos: 6356
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 9.536743e-06
# Mediana Δlat: 0.004529953
# Menor Δlon: 3.8146973e-06
# Mediana Δlon: 0.0041007996
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 39
# Perfis com salto grande (primeiros 10): [ 255  344  546  771  809 1032 1144 1260 1476 1698]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 6356 pontos únicos
# 3 casas decimais → 6356 pontos únicos
# 2 casas decimais → 6353 pontos únicos
# 1 casas decimais → 5900 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00001750_00001999.nc
# Perfis globais: 8247
# Perfis na região: 1311
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 1311
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -49.31409 / 7.94008
# Lon min/max: -49.9683 / -10.00642
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 1311
# Pontos únicos: 1311
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 9.536743e-06
# Mediana Δlat: 0.01516521
# Menor Δlon: 9.536743e-06
# Mediana Δlon: 0.014824867
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 8
# Perfis com salto grande (primeiros 10): [ 233  317  408  439  552  600  972 1288]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 1311 pontos únicos
# 3 casas decimais → 1311 pontos únicos
# 2 casas decimais → 1309 pontos únicos
# 1 casas decimais → 1223 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00002000_00002249.nc
# Perfis globais: 24
# Perfis na região: 0
#
# Processando: argo_00002250_00002499.nc
# Perfis globais: 811
# Perfis na região: 0
#
# Processando: argo_00002500_00002749.nc
# Perfis globais: 142
# Perfis na região: 0
#
# Processando: argo_00002750_00002999.nc
# Perfis globais: 2786
# Perfis na região: 0
#
# Processando: argo_00003000_00003249.nc
# Perfis globais: 9574
# Perfis na região: 0
#
# Processando: argo_00003250_00003499.nc
# Perfis globais: 1534
# Perfis na região: 0
#
# Processando: argo_00003500_00003749.nc
# Perfis globais: 6789
# Perfis na região: 0
#
# Processando: argo_00003750_00003999.nc
# Perfis globais: 12465
# Perfis na região: 0
#
# Processando: argo_00004000_00004249.nc
# Perfis globais: 4126
# Perfis na região: 0
#
# Processando: argo_00004250_00004499.nc
# Perfis globais: 1
# Perfis na região: 0
#
# Processando: argo_00004500_00004749.nc
# Perfis globais: 2864
# Perfis na região: 825
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 825
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -58.159855 / -0.7982
# Lon min/max: -49.882 / -11.006948
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 825
# Pontos únicos: 825
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 8.392334e-05
# Mediana Δlat: 0.019549847
# Menor Δlon: 5.722046e-05
# Mediana Δlon: 0.020899773
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 7
# Perfis com salto grande (primeiros 10): [455 508 511 617 659 719 802]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 825 pontos únicos
# 3 casas decimais → 825 pontos únicos
# 2 casas decimais → 824 pontos únicos
# 1 casas decimais → 777 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00004750_00004999.nc
# Perfis globais: 24114
# Perfis na região: 1318
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 1318
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -55.49302 / -5.22961
# Lon min/max: -49.98053 / -10.266
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 1318
# Pontos únicos: 1318
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 9.536743e-06
# Mediana Δlat: 0.008210182
# Menor Δlon: 9.536743e-06
# Mediana Δlon: 0.008629799
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 7
# Perfis com salto grande (primeiros 10): [   4   32  993 1058 1211 1220 1227]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 1318 pontos únicos
# 3 casas decimais → 1318 pontos únicos
# 2 casas decimais → 1316 pontos únicos
# 1 casas decimais → 1182 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00005000_00005249.nc
# Perfis globais: 14775
# Perfis na região: 1405
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 1405
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -55.718 / -0.74468
# Lon min/max: -49.758 / -10.00089
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 1405
# Pontos únicos: 1405
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 1.1444092e-05
# Mediana Δlat: 0.01080513
# Menor Δlon: 5.722046e-06
# Mediana Δlon: 0.015095711
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 13
# Perfis com salto grande (primeiros 10): [  56  137  379  621  742  743  768  882  911 1284]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 1405 pontos únicos
# 3 casas decimais → 1405 pontos únicos
# 2 casas decimais → 1401 pontos únicos
# 1 casas decimais → 1236 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00005250_00005499.nc
# Perfis globais: 12315
# Perfis na região: 3285
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 3285
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.634415 / 9.96185
# Lon min/max: -49.98417 / -10.008509
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 3285
# Pontos únicos: 3281
# Repetidos exatos: 4
#
# --- Resolução espacial ---
# Menor Δlat: 3.33786e-06
# Mediana Δlat: 0.010540009
# Menor Δlon: 5.722046e-06
# Mediana Δlon: 0.0077056885
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 43
# Perfis com salto grande (primeiros 10): [361 373 378 444 484 572 638 700 718 818]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 3281 pontos únicos
# 3 casas decimais → 3281 pontos únicos
# 2 casas decimais → 3272 pontos únicos
# 1 casas decimais → 3047 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00005500_00005749.nc
# Perfis globais: 524
# Perfis na região: 0
#
# Processando: argo_00005750_00005999.nc
# Perfis globais: 451
# Perfis na região: 0
#
# Processando: argo_00006000_00006249.nc
# Perfis globais: 790
# Perfis na região: 2
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 2
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: 9.561 / 9.948
# Lon min/max: -38.237 / -38.046
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 2
# Pontos únicos: 2
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.38700008
# Mediana Δlat: 0.38700008
# Menor Δlon: 0.19099808
# Mediana Δlon: 0.19099808
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 2 pontos únicos
# 3 casas decimais → 2 pontos únicos
# 2 casas decimais → 2 pontos únicos
# 1 casas decimais → 2 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00006250_00006499.nc
# Perfis globais: 3441
# Perfis na região: 277
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 277
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -9.996 / 9.966
# Lon min/max: -39.049 / -11.094
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 277
# Pontos únicos: 277
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0005030632
# Mediana Δlat: 0.014499664
# Menor Δlon: 9.346008e-05
# Mediana Δlon: 0.03047371
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 2
# Perfis com salto grande (primeiros 10): [  5 163]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 277 pontos únicos
# 3 casas decimais → 277 pontos únicos
# 2 casas decimais → 277 pontos únicos
# 1 casas decimais → 256 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00006500_00006749.nc
# Perfis globais: 24799
# Perfis na região: 853
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 853
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -43.51413 / 9.98863
# Lon min/max: -49.98848 / -17.37
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 853
# Pontos únicos: 853
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 9.536743e-06
# Mediana Δlat: 0.0029497147
# Menor Δlon: 1.1444092e-05
# Mediana Δlon: 0.011224747
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 3
# Perfis com salto grande (primeiros 10): [ 25 182 192]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 853 pontos únicos
# 3 casas decimais → 853 pontos únicos
# 2 casas decimais → 848 pontos únicos
# 1 casas decimais → 691 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00006750_00006999.nc
# Perfis globais: 18463
# Perfis na região: 0
#
# Processando: argo_00007000_00007249.nc
# Perfis globais: 14298
# Perfis na região: 0
#
# Processando: argo_00007250_00007499.nc
# Perfis globais: 3282
# Perfis na região: 28
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 28
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: 8.00435 / 9.85622
# Lon min/max: -45.77205 / -43.74047
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 28
# Pontos únicos: 28
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0010595322
# Mediana Δlat: 0.0329504
# Menor Δlon: 0.00036239624
# Mediana Δlon: 0.049861908
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 28 pontos únicos
# 3 casas decimais → 28 pontos únicos
# 2 casas decimais → 28 pontos únicos
# 1 casas decimais → 25 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00007500_00007749.nc
# Perfis globais: 237
# Perfis na região: 0
#
# Processando: argo_00007750_00007999.nc
# Perfis globais: 7
# Perfis na região: 0
#
# Processando: argo_00008000_00008249.nc
# Perfis globais: 678
# Perfis na região: 0
#
# Processando: argo_00008250_00008499.nc
# Perfis globais: 1026
# Perfis na região: 0
#
# Processando: argo_00008500_00008749.nc
# Perfis globais: 7632
# Perfis na região: 1082
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 1082
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.844 / -26.906
# Lon min/max: -49.946 / -10.038
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 1082
# Pontos únicos: 1082
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.00021743774
# Mediana Δlat: 0.011001587
# Menor Δlon: 0.0002784729
# Mediana Δlon: 0.021000862
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 10
# Perfis com salto grande (primeiros 10): [  9 150 236 274 402 529 659 765 845 963]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 1082 pontos únicos
# 3 casas decimais → 1082 pontos únicos
# 2 casas decimais → 1082 pontos únicos
# 1 casas decimais → 1069 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00008750_00008999.nc
# Perfis globais: 4742
# Perfis na região: 27
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 27
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.991 / -58.29
# Lon min/max: -18.756 / -10.246
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 27
# Pontos únicos: 27
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.008998871
# Mediana Δlat: 0.041635513
# Menor Δlon: 0.035125732
# Mediana Δlon: 0.24100018
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 27 pontos únicos
# 3 casas decimais → 27 pontos únicos
# 2 casas decimais → 27 pontos únicos
# 1 casas decimais → 27 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00009000_00009249.nc
# Perfis globais: 2652
# Perfis na região: 445
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 445
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -58.501 / -40.446
# Lon min/max: -49.996 / -12.74
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 445
# Pontos únicos: 445
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.020000458
# Menor Δlon: 0.0009994507
# Mediana Δlon: 0.035999298
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 3
# Perfis com salto grande (primeiros 10): [ 98 172 354]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 445 pontos únicos
# 3 casas decimais → 445 pontos únicos
# 2 casas decimais → 445 pontos únicos
# 1 casas decimais → 440 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00009250_00009499.nc
# Perfis globais: 15194
# Perfis na região: 3
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 3
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -58.09907 / -57.42437
# Lon min/max: -48.81525 / -47.63963
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 3
# Pontos únicos: 3
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.21591187
# Mediana Δlat: 0.33735085
# Menor Δlon: 0.046360016
# Mediana Δlon: 0.5878105
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 3 pontos únicos
# 3 casas decimais → 3 pontos únicos
# 2 casas decimais → 3 pontos únicos
# 1 casas decimais → 3 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00009500_00009749.nc
# Perfis globais: 16384
# Perfis na região: 591
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 591
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.736 / 9.95
# Lon min/max: -48.278 / -18.623
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 591
# Pontos únicos: 591
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009999275
# Mediana Δlat: 0.0149998665
# Menor Δlon: 0.0009994507
# Mediana Δlon: 0.020000458
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 4
# Perfis com salto grande (primeiros 10): [103 155 506 584]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 591 pontos únicos
# 3 casas decimais → 591 pontos únicos
# 2 casas decimais → 591 pontos únicos
# 1 casas decimais → 553 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00009750_00009999.nc
# Perfis globais: 12120
# Perfis na região: 0
#
# Processando: argo_00010000_00010249.nc
# Perfis globais: 21802
# Perfis na região: 111
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 111
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -56.593 / -43.55748
# Lon min/max: -49.968 / -11.1442
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 111
# Pontos únicos: 111
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.00038146973
# Mediana Δlat: 0.053710938
# Menor Δlon: 0.0032997131
# Mediana Δlon: 0.10562706
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 1
# Perfis com salto grande (primeiros 10): [41]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 111 pontos únicos
# 3 casas decimais → 111 pontos únicos
# 2 casas decimais → 111 pontos únicos
# 1 casas decimais → 109 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00010250_00010499.nc
# Perfis globais: 21173
# Perfis na região: 39
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 39
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -55.62791 / -48.783
# Lon min/max: -49.922 / -23.883
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 39
# Pontos únicos: 39
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.11099815
# Menor Δlon: 0.00799942
# Mediana Δlon: 0.34400177
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 1
# Perfis com salto grande (primeiros 10): [32]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 39 pontos únicos
# 3 casas decimais → 39 pontos únicos
# 2 casas decimais → 39 pontos únicos
# 1 casas decimais → 39 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00010500_00010749.nc
# Perfis globais: 41162
# Perfis na região: 125
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 125
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -46.359 / -26.713
# Lon min/max: -30.003 / -10.05
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 125
# Pontos únicos: 125
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.025000572
# Menor Δlon: 0.0019989014
# Mediana Δlon: 0.09349966
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 1
# Perfis com salto grande (primeiros 10): [38]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 125 pontos únicos
# 3 casas decimais → 125 pontos únicos
# 2 casas decimais → 125 pontos únicos
# 1 casas decimais → 121 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00010750_00010999.nc
# Perfis globais: 21517
# Perfis na região: 133
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 133
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -57.215 / -44.287
# Lon min/max: -49.963 / -17.837
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 133
# Pontos únicos: 133
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.02999878
# Menor Δlon: 0.0009994507
# Mediana Δlon: 0.066999435
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 4
# Perfis com salto grande (primeiros 10): [122 123 126 129]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 133 pontos únicos
# 3 casas decimais → 133 pontos únicos
# 2 casas decimais → 132 pontos únicos
# 1 casas decimais → 121 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00011000_00011249.nc
# Perfis globais: 18142
# Perfis na região: 600
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 600
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.444 / 5.824
# Lon min/max: -49.818 / -10.648
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 600
# Pontos únicos: 600
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0009994507
# Mediana Δlat: 0.01499939
# Menor Δlon: 0.0009994507
# Mediana Δlon: 0.019001007
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 11
# Perfis com salto grande (primeiros 10): [  2   6  58  64  66 446 501 503 537 538]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 600 pontos únicos
# 3 casas decimais → 600 pontos únicos
# 2 casas decimais → 599 pontos únicos
# 1 casas decimais → 532 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00011250_00011499.nc
# Perfis globais: 11864
# Perfis na região: 0
#
# Processando: argo_00011500_00011749.nc
# Perfis globais: 4895
# Perfis na região: 37
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 37
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -55.975 / -14.873
# Lon min/max: -48.299 / -22.849
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 37
# Pontos únicos: 37
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0019989014
# Mediana Δlat: 0.121500015
# Menor Δlon: 0.0069999695
# Mediana Δlon: 0.30800152
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 4
# Perfis com salto grande (primeiros 10): [ 1 22 30 32]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 37 pontos únicos
# 3 casas decimais → 37 pontos únicos
# 2 casas decimais → 37 pontos únicos
# 1 casas decimais → 35 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00011750_00011999.nc
# Perfis globais: 1788
# Perfis na região: 0
#
# Processando: argo_00012000_00012249.nc
# Perfis globais: 1162
# Perfis na região: 30
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 30
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -58.13083 / -7.658
# Lon min/max: -47.810966 / -27.056
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 30
# Pontos únicos: 30
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.010543823
# Mediana Δlat: 0.07480621
# Menor Δlon: 0.032726288
# Mediana Δlon: 0.24471474
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 2
# Perfis com salto grande (primeiros 10): [ 0 10]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 30 pontos únicos
# 3 casas decimais → 30 pontos únicos
# 2 casas decimais → 30 pontos únicos
# 1 casas decimais → 30 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00012250_00012499.nc
# Perfis globais: 1943
# Perfis na região: 0
#
# Processando: argo_00012500_00012749.nc
# Perfis globais: 4423
# Perfis na região: 56
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 56
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -18.559177 / 9.99871
# Lon min/max: -28.773245 / -22.224459
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 56
# Pontos únicos: 56
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.00012493134
# Mediana Δlat: 0.005519867
# Menor Δlon: 0.0010128021
# Mediana Δlon: 0.02123642
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 1
# Perfis com salto grande (primeiros 10): [45]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 56 pontos únicos
# 3 casas decimais → 56 pontos únicos
# 2 casas decimais → 55 pontos únicos
# 1 casas decimais → 36 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00012750_00012999.nc
# Perfis globais: 3444
# Perfis na região: 21
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 21
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -9.958312 / -7.4219165
# Lon min/max: -32.493366 / -29.477709
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 21
# Pontos únicos: 21
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.0015563965
# Mediana Δlat: 0.092500925
# Menor Δlon: 0.025669098
# Mediana Δlon: 0.12901402
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 0
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 21 pontos únicos
# 3 casas decimais → 21 pontos únicos
# 2 casas decimais → 21 pontos únicos
# 1 casas decimais → 21 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00013000_00013249.nc
# Perfis globais: 6601
# Perfis na região: 231
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 231
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -21.413776 / 9.992953
# Lon min/max: -45.910545 / -10.279919
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 231
# Pontos únicos: 231
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 3.4332275e-05
# Mediana Δlat: 0.01796171
# Menor Δlon: 0.0004119873
# Mediana Δlon: 0.026619911
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 4
# Perfis com salto grande (primeiros 10): [ 41  42  93 120]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 231 pontos únicos
# 3 casas decimais → 231 pontos únicos
# 2 casas decimais → 231 pontos únicos
# 1 casas decimais → 191 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00013250_00013499.nc
# Perfis globais: 8464
# Perfis na região: 75
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 75
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.866 / 0.5993933
# Lon min/max: -49.461 / -10.032
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 75
# Pontos únicos: 75
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 0.00018332899
# Mediana Δlat: 0.05476682
# Menor Δlon: 0.002811432
# Mediana Δlon: 0.34013653
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 1
# Perfis com salto grande (primeiros 10): [27]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 75 pontos únicos
# 3 casas decimais → 75 pontos únicos
# 2 casas decimais → 75 pontos únicos
# 1 casas decimais → 75 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00013500_00013749.nc
# Perfis globais: 11419
# Perfis na região: 1073
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 1073
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -59.4218 / -35.2269
# Lon min/max: -49.88089 / -10.02193
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 1073
# Pontos únicos: 1072
# Repetidos exatos: 1
#
# --- Resolução espacial ---
# Menor Δlat: 1.9073486e-05
# Mediana Δlat: 0.0100803375
# Menor Δlon: 0.00017929077
# Mediana Δlon: 0.026605606
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 17
# Perfis com salto grande (primeiros 10): [ 91 181 234 262 354 390 423 485 561 680]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 1072 pontos únicos
# 3 casas decimais → 1072 pontos únicos
# 2 casas decimais → 1072 pontos únicos
# 1 casas decimais → 1047 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: argo_00013750_00013831.nc
# Perfis globais: 4648
# Perfis na região: 287
#
# ================ DIAGNÓSTICO ESPACIAL ================
# Total de perfis analisados: 287
#
# --- Valores inválidos ---
# Lat NaN: 0
# Lon NaN: 0
# Lat Inf: 0
# Lon Inf: 0
#
# --- Faixa de valores ---
# Lat min/max: -57.15199 / -39.50747
# Lon min/max: -49.82484 / -10.22804
# 🌍 Longitude parece estar em -180–180
#
# --- Repetição exata ---
# Total pontos: 287
# Pontos únicos: 287
# Repetidos exatos: 0
#
# --- Resolução espacial ---
# Menor Δlat: 8.010864e-05
# Mediana Δlat: 0.038362503
# Menor Δlon: 0.00019073486
# Mediana Δlon: 0.070495605
#
# --- Saltos espaciais entre perfis consecutivos ---
# Saltos >10° encontrados: 3
# Perfis com salto grande (primeiros 10): [ 69 147 229]
#
# --- Sensibilidade ao arredondamento ---
# 4 casas decimais → 287 pontos únicos
# 3 casas decimais → 287 pontos únicos
# 2 casas decimais → 286 pontos únicos
# 1 casas decimais → 279 pontos únicos
#
# ================ FIM DO DIAGNÓSTICO ==================
#
#
# Processando: itp_00000000_00000009.nc
# Perfis globais: 4537
# Perfis na região: 0
#
# Processando: itp_00000010_00000019.nc
# Perfis globais: 6375
# Perfis na região: 0
#
# Processando: itp_00000020_00000029.nc
# Perfis globais: 4301
# Perfis na região: 0
#
# Processando: itp_00000030_00000039.nc
# Perfis globais: 6586
# Perfis na região: 0
#
# Processando: itp_00000040_00000049.nc
# Perfis globais: 4275
# Perfis na região: 0
#
# Processando: itp_00000050_00000059.nc
# Perfis globais: 5791
# Perfis na região: 0
#
# Processando: itp_00000060_00000069.nc
# Perfis globais: 4350
# Perfis na região: 0
#
# Processando: itp_00000070_00000079.nc
# Perfis globais: 4469
# Perfis na região: 0
#
# Processando: itp_00000080_00000084.nc
# Perfis globais: 1689
# Perfis na região: 0
#
# ================ RESULTADOS ==================
#
# ----- PERFIS -----
# Perfis globais: 487493
# Perfis na região: 21370
# Perfis com escada: 17468
# Perfis SF: 13845
# Perfis DC: 10538
# Perfis mistos: 6915
#
# Frequência total de escadas: 81.74 %
#
# ----- PONTOS ÚNICOS -----
# Pontos únicos na região: 21328
# Pontos únicos com escada: 17440
# Pontos únicos SF: 13828
# Pontos únicos DC: 10525
# Pontos únicos mistos: 6910
# Frequência espacial total: 81.77 %
#
# ----- ESTATÍSTICAS VERTICAIS -----
# Profundidade média ML SF: 964.1 dbar
# Profundidade média ML DC: 981.7 dbar
# Espessura média ML SF: 9.75 dbar
# Espessura média ML DC: 11.01 dbar
# Número médio de camadas SF: 69.71
# Número médio de camadas DC: 79.81

# %%
#poontos
only_sf = len(unique_points_sf) - len(unique_points_mixed)
only_dc = len(unique_points_dc) - len(unique_points_mixed)

total_union = len(unique_points_sf | unique_points_dc)

print("Apenas SF:", only_sf, round(100 * only_sf / total_union, 2), "%")
print("Apenas DC:", only_dc, round(100 * only_dc / total_union, 2), "%")
print("Mistos:", len(unique_points_mixed), round(100 * len(unique_points_mixed) / total_union, 2), "%")
# Out:
# Apenas SF: 6918 39.67 %
# Apenas DC: 3615 20.73 %
# Mistos: 6910 39.62 %
